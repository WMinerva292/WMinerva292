# %% [markdown]
# <a href="https://colab.research.google.com/github/WMinerva292/WMinerva292/blob/main/Panda_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install panda
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7239 sha256=725d4f2f4da83e8078c10b70cccde973da3348669cc40fabe77fdff8d0058e3a
#   Stored in directory: /root/.cache/pip/wheels/0e/8b/c3/ff9cbde1fffd8071cff8367a86f0350a1ce30a8d31b6a432e9
# Successfully built panda
# ...

# %% [markdown]
# Configuring Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Lets import the datafile

# %%
# lets import the .csv file
data = pd.read_csv('/content/housing.csv')

# %%
data
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
data.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.tail()
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.shape
# Out:
# (21613, 21)

# %%
data.dtypes
# Out:
# id                 int64
# date              object
# price              int64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# Find the zip code with costliest house
data.sort_values(by='price',ascending=False).head(1)
# Out:
#               id             date    price  bedrooms  bathrooms  sqft_living  \
# 7252  6762700020  20141013T000000  7700000         6        8.0        12050
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252     27600     2.5           0     3  ...     13        8570
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252           3480      1910          1987    98102  47.6298 -122.323
#
#       sqft_living15  sqft_lot15
# 7252           3940        8800
#
# [1 rows x 21 columns]

# %%
# Number of houses having grade 10
(data[data['grade']==10])
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 66     3394100030  20140909T000000   975000         4       2.50         2720
# 75     3276920270  20141105T000000   832500         4       4.00         3430
# 79     1531000030  20150323T000000   720000         4       2.50         3450
# 91     5036300431  20150311T000000  1099880         5       2.75         3520
# 108    1853000400  20150305T000000   680000         4       2.50         3140
# ...           ...              ...      ...       ...        ...          ...
# 21568   524059330  20150130T000000  1700000         4       3.50         3830
# 21573  8562790760  20140520T000000   785000         4       3.50         3070
# 21576  9253900271  20150107T000000  3567000         5       4.50         4850
# 21593  8672200110  20150317T000000  1088000         5       3.75         4170
# 21597   191100405  20150421T000000  1575000         4       3.25         3410
#
# ...

# %%
# Does this 9126100861 customer have waterfront?
data[data['zipcode'] == 9126100861]['waterfront']
# Out:
# Series([], Name: waterfront, dtype: int64)

# %%
# Number of houses with 3 views
data[data['view']==3].shape[0]
# Out:
# 510

# %%
# Lowest price of the house
data['price'].min()
# Out:
# 75000

# %%
# Which area has the biggest sqft_living?
data.sort_values(by='sqft_living',ascending=False).head(1)
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 12777  1225069038  20140505T000000  2280000         7        8.0        13540
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 12777    307752     3.0           0     4  ...     12        9410
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 12777           4130      1999             0    98053  47.6675 -121.986
#
#        sqft_living15  sqft_lot15
# 12777           4850      217800
#
# [1 rows x 21 columns]

# %%
# Check duplicate values on id, grade and location
data.duplicated(subset=['id','grade','zipcode']).sum()
# Out:
# 177

# %%
# Getting the houses where no. of bedrooms is maximum having 3 views along with 1 waterfront
data[(data['view']==3) & (data['waterfront']==1)].sort_values(by='bedrooms',ascending=False).head(1)
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 16570  2923039243  20141113T000000  340000         4        1.0         1200
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 16570     11834     1.0           1     3  ...      6        1200
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 16570              0      1972             0    98070  47.4557 -122.443
#
#        sqft_living15  sqft_lot15
# 16570           1670       47462
#
# [1 rows x 21 columns]

# %%
# correlation between the columns sqft_living and sqft_above?
data['sqft_living'].corr(data['sqft_above'])
# Out:
# 0.876596598681318
